# %%
import pandas as pd

# %%
df_clients = pd.read_csv('../../data/datasets/x5-retail-hero/clients.csv.gz', index_col='client_id')
df_train = pd.read_csv('../../data/datasets/x5-retail-hero/uplift_train.csv.gz', index_col='client_id')
df_test = pd.read_csv('../../data/datasets/x5-retail-hero/uplift_test.csv.gz', index_col='client_id')

# %% [markdown]
# # Client only features

# %% [markdown]
# ### Normalize dates by 1 year

# %%
df_features = df_clients.copy()

df_features['first_issue_time'] = \
    (pd.to_datetime(df_features['first_issue_date'])
     - pd.to_datetime(df_features['first_issue_date']).min()) / pd.Timedelta('365d')

df_features['first_redeem_time'] = \
    (pd.to_datetime(df_features['first_redeem_date'])
     - pd.to_datetime(df_features['first_redeem_date']).min()) / pd.Timedelta('365d')

# %% [markdown]
# ### redeem - issue dates

# %%
df_features['issue_redeem_delay'] = df_features['first_redeem_time'] \
    - df_features['first_issue_time']

# %% [markdown]
# ### Make gender OHE

# %%
df_features = df_features.join(pd.get_dummies(df_features['gender']))

# %% [markdown]
# ### Fill NA with means

# %%
df_features['first_redeem_time'] = df_features['first_redeem_time'].fillna(df_features['first_redeem_time'].mean())
df_features['issue_redeem_delay'] = df_features['issue_redeem_delay'].fillna(df_features['issue_redeem_delay'].mean())

# %% [markdown]
# ### Drop redundant features

# %%
df_features = df_features.drop(['first_issue_date', 'first_redeem_date', 'gender'], axis=1)

# %%
df_features
# Out:
#             age  first_issue_time  first_redeem_time  issue_redeem_delay  F  \
# client_id
# 000012768d   45          0.336675           0.735365            0.398690  0
# 000036f903   72          0.015925           0.033211            0.017286  1
# 000048b7a6   68          1.698076           1.208236            0.476130  1
# 000073194a   60          0.133622           0.622100            0.488477  1
# 00007c7133   67          0.131265           1.724154            1.592889  0
# ...         ...               ...                ...                 ... ..
# fffece623e   67          1.106479           1.713402            0.606924  0
# ffff3dfff8   56          1.577821           1.658431            0.080611  1
# ffffaab9da   23          0.391817           0.661208            0.269391  1
# ffffeb5619   62          0.670666           1.208236            0.476130  0
# fffff6ce77   42          0.331737           0.376140            0.044403  0
#
#             M  U
# client_id
# 000012768d  0  1
# 000036f903  0  0
# 000048b7a6  0  0
# 000073194a  0  0
# 00007c7133  0  1
# ...        .. ..
# fffece623e  0  1
# ffff3dfff8  0  0
# ffffaab9da  0  0
# ffffeb5619  0  1
# fffff6ce77  0  1
#
# [400162 rows x 7 columns]

# %%
df_train.shape
# Out:
# (200039, 2)

# %%
df_test.shape
# Out:
# (200123, 0)

# %%
df_features.to_csv("../../data/preprocessed/client_features.csv")

# %% [markdown]
# # Read jsonl

# %%
import json
from pprint import pprint

def loader(path):
    with open(path, "r") as f:
        for line in f.readlines():
            yield json.loads(line)
            
for line in loader("../../data/preprocessed/x5-retail-hero/tmp/jsons/00.jsons.splitted"):
    pprint(line)
    break
# Out:
# {'age': 34,
#  'client_id': '0000bcec9c',
#  'gender': 'U',
#  'target': [{'datetime': '2019-03-03 10:54:09',
#              'product_ids': ['233eead1ad'],
#              'store_id': '1a346a89e1',
#              'tid': '8b5360c3ba'},
#             {'datetime': '2019-03-03 15:13:17',
#              'product_ids': ['5b379f22d4'],
#              'store_id': '1a346a89e1',
#              'tid': 'c57538fd1a'},
#             {'datetime': '2019-03-04 08:57:46',
#              'product_ids': ['baba8b097d'],
#              'store_id': 'b1b62ce494',
#              'tid': '2413ccdd82'},
#             {'datetime': '2019-03-05 01:08:23',
#              'product_ids': ['26af08d169',
#                              'ea27d5dc75',
#                              '8fec8d8366',
#                              '3c2684d2e5',
#                              '75c1a51a7e'],
#              'store_id': '1a346a89e1',
#              'tid': 'f8009d804b'},
#             {'datetime': '2019-03-06 13:39:58',
#              'product_ids': ['ad865591c6'],
#              'store_id': '1a346a89e1',
#              'tid': '068cb58b07'},
#             {'datetime': '2019-03-11 11:03:14',
#              'product_ids': ['c994d88e36',
#                              '4dcf79043e',
#                              '4a7946e374',
#                              '5cb93c9bc5',
#                              'a14468af70',
#                              'eef2500766',
#                              '168a164753',
#                              '85a4571042',
#                              '262509c05d'],
#              'store_id': '1a346a89e1',
#              'tid': 'd76ea4a6a9'},
#             {'datetime': '2019-03-13 15:24:18',
#              'product_ids': ['0446066c06',
#                              'bfedd7b9f5',
#                              'ebc2d45eb5',
#                              'a819b4e007',
#                              '168a164753',
#                              'e94747c0fc',
#                              'defc05e5cd',
#                              'e7325b4d3a'],
#              'store_id': '1a346a89e1',
#              'tid': 'ff88afde59'},
#             {'datetime': '2019-03-14 14:29:29',
#              'product_ids': ['77b36569e2',
#                              '925d3cc556',
#                              '74cb1169ca',
#                              '3e3fbf17ec',
#                              '416ecbe1c7',
#                              '3e038662c0',
#                              '6d024faac2',
#                              '168a164753',
#                              'c92d9a946f',
#                              'c4ec937ca8'],
#              'store_id': '1a346a89e1',
#              'tid': '8efc708814'},
#             {'datetime': '2019-03-16 16:59:40',
#              'product_ids': ['168a164753'],
#              'store_id': '1a346a89e1',
#              'tid': '714955f51f'}],
#  'transaction_history': [{'datetime': '2018-11-28 12:12:51',
#                           'epr': 0.0,
#                           'eps': 0.0,
#                           'products': [{'product_id': '233eead1ad',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 54.0},
#                                        {'product_id': '77b36569e2',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 54.0}],
#                           'rpr': 0.5,
#                           'rps': 0.0,
#                           'store_id': '1a346a89e1',
#                           'sum': 107.0,
#                           'tid': '4e5a8c9937'},
#                          {'datetime': '2018-12-03 11:57:24',
#                           'epr': 0.0,
#                           'eps': 0.0,
#                           'products': [{'product_id': 'da1c4af3c0',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 49.0},
#                                        {'product_id': 'f81883a45f',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 50.0},
#                                        {'product_id': '94b62ffa40',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 75.0},
#                                        {'product_id': 'e64a9944f2',
#                                         'quantity': 0.0,
#                                         'r': '0',
#                                         's': 28.0}],
#                           'rpr': 1.0,
#                           'rps': 0.0,
#                           'store_id': '1a346a89e1',
#                           'sum': 202.0,
#                           'tid': '4e56420624'},
#                          {'datetime': '2018-12-03 14:10:10',
#                           'epr': 0.0,
#                           'eps': 0.0,
#                           'products': [{'product_id': 'da1c4af3c0',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 49.0},
#                                        {'product_id': 'ae4e689751',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 56.0}],
#                           'rpr': 0.5,
#                           'rps': 0.0,
#                           'store_id': '1a346a89e1',
#                           'sum': 104.0,
#                           'tid': 'b257208e11'},
#                          {'datetime': '2018-12-04 11:43:06',
#                           'epr': 0.0,
#                           'eps': 0.0,
#                           'products': [{'product_id': '796a39257e',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 12.0},
#                                        {'product_id': 'f7724d5786',
#                                         'quantity': 0.0,
#                                         'r': '0',
#                                         's': 39.0},
#                                        {'product_id': '4dcf79043e',
#                                         'quantity': 2.0,
#                                         'r': '0',
#                                         's': 80.0},
#                                        {'product_id': '15ccaa8685',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 41.0},
#                                        {'product_id': '94b62ffa40',
#                                         'quantity': 2.0,
#                                         'r': '0',
#                                         's': 150.0},
#                                        {'product_id': '3e038662c0',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 36.0}],
#                           'rpr': 1.7,
#                           'rps': 0.0,
#                           'store_id': '1a346a89e1',
#                           'sum': 357.62,
#                           'tid': '1ac38bc5b2'},
#                          {'datetime': '2018-12-05 15:49:48',
#                           'epr': 0.0,
#                           'eps': 0.0,
#                           'products': [{'product_id': 'ac81544ebc',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 11.0}],
#                           'rpr': 0.0,
#                           'rps': 0.0,
#                           'store_id': '1a346a89e1',
#                           'sum': 11.0,
#                           'tid': '67babc6e87'},
#                          {'datetime': '2018-12-06 15:40:15',
#                           'epr': 0.0,
#                           'eps': 0.0,
#                           'products': [{'product_id': '171432aaab',
#                                         'quantity': 2.0,
#                                         'r': '0',
#                                         's': 40.0}],
#                           'rpr': 0.1,
#                           'rps': 0.0,
#                           'store_id': '1a346a89e1',
#                           'sum': 39.0,
#                           'tid': '12fdd0858e'},
#                          {'datetime': '2018-12-06 18:02:55',
#                           'epr': 0.0,
#                           'eps': 0.0,
#                           'products': [{'product_id': '35a66faec4',
#                                         'quantity': 2.0,
#                                         'r': '0',
#                                         's': 166.0},
#                                        {'product_id': '60cfb8a144',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 55.0},
#                                        {'product_id': '4d83be88c5',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 55.0}],
#                           'rpr': 1.3,
#                           'rps': 0.0,
#                           'store_id': '1a346a89e1',
#                           'sum': 275.96,
#                           'tid': '1f7123b312'},
#                          {'datetime': '2018-12-13 09:48:53',
#                           'epr': 0.0,
#                           'eps': 0.0,
#                           'products': [{'product_id': 'ea27d5dc75',
#                                         'quantity': 2.0,
#                                         'r': '0',
#                                         's': 195.0}],
#                           'rpr': 0.9,
#                           'rps': 0.0,
#                           'store_id': '1a346a89e1',
#                           'sum': 195.0,
#                           'tid': '2f00118939'},
#                          {'datetime': '2018-12-14 11:47:41',
#                           'epr': 0.0,
#                           'eps': 0.0,
#                           'products': [{'product_id': '5645789fdf',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 101.0},
#                                        {'product_id': '5cb93c9bc5',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 20.0},
#                                        {'product_id': '3e038662c0',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 73.0},
#                                        {'product_id': '8b6b7e8dbf',
#                                         'quantity': 2.0,
#                                         'r': '0',
#                                         's': 200.0},
#                                        {'product_id': 'fe382e4808',
#                                         'quantity': 2.0,
#                                         'r': '0',
#                                         's': 180.0},
#                                        {'product_id': '94b62ffa40',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 75.0},
#                                        {'product_id': 'b29510626d',
#                                         'quantity': 4.0,
#                                         'r': '0',
#                                         's': 220.0},
#                                        {'product_id': '4dcf79043e',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 40.0},
#                                        {'product_id': 'b892da209f',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 86.0},
#                                        {'product_id': '122534de50',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 56.0}],
#                           'rpr': 10.5,
#                           'rps': 0.0,
#                           'store_id': '1a346a89e1',
#                           'sum': 1051.0,
#                           'tid': '84ecbb1117'},
#                          {'datetime': '2018-12-16 15:20:28',
#                           'epr': 0.0,
#                           'eps': 0.0,
#                           'products': [{'product_id': 'ae4e689751',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 58.0},
#                                        {'product_id': '5b903bb574',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 190.0}],
#                           'rpr': 1.2,
#                           'rps': 0.0,
#                           'store_id': '1a346a89e1',
#                           'sum': 248.48,
#                           'tid': 'b901854968'},
#                          {'datetime': '2018-12-17 09:54:22',
#                           'epr': 0.0,
#                           'eps': 0.0,
#                           'products': [{'product_id': '94b62ffa40',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 67.0},
#                                        {'product_id': 'ea27d5dc75',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 148.0},
#                                        {'product_id': '4009f09b04',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 5.0},
#                                        {'product_id': 'f7442ec69d',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 39.0},
#                                        {'product_id': '4a29330c8d',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 61.0}],
#                           'rpr': 1.6,
#                           'rps': 0.0,
#                           'store_id': '1a346a89e1',
#                           'sum': 320.17,
#                           'tid': 'a51d2ed6e3'},
#                          {'datetime': '2018-12-17 14:39:14',
#                           'epr': 0.0,
#                           'eps': 0.0,
#                           'products': [{'product_id': 'f098ee2a85',
#                                         'quantity': 0.0,
#                                         'r': '0',
#                                         's': 61.0},
#                                        {'product_id': 'aa1c203a47',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 180.0},
#                                        {'product_id': '5557d5f608',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 69.0},
#                                        {'product_id': '377153d516',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 65.0},
#                                        {'product_id': 'c85e209e7d',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 40.0}],
#                           'rpr': 2.0,
#                           'rps': 0.0,
#                           'store_id': '1a346a89e1',
#                           'sum': 414.7,
#                           'tid': '8660654eae'},
#                          {'datetime': '2018-12-19 12:45:37',
#                           'epr': 0.0,
#                           'eps': 0.0,
#                           'products': [{'product_id': '3e038662c0',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 42.0},
#                                        {'product_id': '94b62ffa40',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 75.0}],
#                           'rpr': 0.5,
#                           'rps': 0.0,
#                           'store_id': '1a346a89e1',
#                           'sum': 116.0,
#                           'tid': '76f1aeb0e1'},
#                          {'datetime': '2018-12-20 13:07:21',
#                           'epr': 0.0,
#                           'eps': 0.0,
#                           'products': [{'product_id': 'e7325b4d3a',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 67.0},
#                                        {'product_id': '0bae38c4fb',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 67.0},
#                                        {'product_id': 'f43c12d228',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 24.0},
#                                        {'product_id': '4dcf79043e',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 40.0},
#                                        {'product_id': '4bd01c5234',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 65.0},
#                                        {'product_id': '15ccaa8685',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 64.0},
#                                        {'product_id': 'd820b822dd',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 249.0},
#                                        {'product_id': '2bd188411e',
#                                         'quantity': 0.0,
#                                         'r': '0',
#                                         's': 144.0},
#                                        {'product_id': '2b9b5bbe40',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 28.0},
#                                        {'product_id': 'be08fb62f4',
#                                         'quantity': 2.0,
#                                         'r': '0',
#                                         's': 166.0}],
#                           'rpr': 9.1,
#                           'rps': 0.0,
#                           'store_id': '1a346a89e1',
#                           'sum': 914.79,
#                           'tid': '65f9612b98'},
#                          {'datetime': '2018-12-21 09:28:42',
#                           'epr': 0.0,
#                           'eps': 0.0,
#                           'products': [{'product_id': '233eead1ad',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 59.0},
#                                        {'product_id': 'e6a5597d19',
#                                         'quantity': 2.0,
#                                         'r': '0',
#                                         's': 13.0},
#                                        {'product_id': '94b62ffa40',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 71.0},
#                                        {'product_id': '7eb0c4ee79',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 42.0},
#                                        {'product_id': '35a66faec4',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 79.0}],
#                           'rpr': 1.3,
#                           'rps': 0.0,
#                           'store_id': '1a346a89e1',
#                           'sum': 264.0,
#                           'tid': 'cfe79ee178'},
#                          {'datetime': '2018-12-31 07:30:09',
#                           'epr': 0.0,
#                           'eps': 0.0,
#                           'products': [{'product_id': '810ae73382',
#                                         'quantity': 2.0,
#                                         'r': '0',
#                                         's': 13.0},
#                                        {'product_id': 'b44b9c16df',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 100.0},
#                                        {'product_id': 'fb24d36033',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 66.0}],
#                           'rpr': 0.8,
#                           'rps': 0.0,
#                           'store_id': '1a346a89e1',
#                           'sum': 179.0,
#                           'tid': '74f634bcfc'},
#                          {'datetime': '2018-12-31 12:00:16',
#                           'epr': 0.0,
#                           'eps': 0.0,
#                           'products': [{'product_id': '8679f046b0',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 41.0}],
#                           'rpr': 0.2,
#                           'rps': 0.0,
#                           'store_id': '1a346a89e1',
#                           'sum': 39.0,
#                           'tid': '858d8dbe06'},
#                          {'datetime': '2019-01-01 13:05:06',
#                           'epr': 0.0,
#                           'eps': 0.0,
#                           'products': [{'product_id': '5b379f22d4',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 65.0}],
#                           'rpr': 0.3,
#                           'rps': 0.0,
#                           'store_id': '1a346a89e1',
#                           'sum': 64.0,
#                           'tid': '3014b4643a'},
#                          {'datetime': '2019-01-03 19:41:13',
#                           'epr': 0.0,
#                           'eps': 0.0,
#                           'products': [{'product_id': '40c75f7dfa',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 58.0},
#                                        {'product_id': 'fa414ebe87',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 62.0},
#                                        {'product_id': 'a98612c66a',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 70.0},
#                                        {'product_id': '60aa1f7a1f',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 55.0},
#                                        {'product_id': 'b4ca80b92d',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 79.0},
#                                        {'product_id': '63d04ba521',
#                                         'quantity': 6.0,
#                                         'r': '0',
#                                         's': 282.0},
#                                        {'product_id': 'b879ff41f3',
#                                         'quantity': 3.0,
#                                         'r': '0',
#                                         's': 180.0},
#                                        {'product_id': '08b41f51e5',
#                                         'quantity': 2.0,
#                                         'r': '0',
#                                         's': 53.0},
#                                        {'product_id': 'ab8ab5dc34',
#                                         'quantity': 2.0,
#                                         'r': '0',
#                                         's': 200.0},
#                                        {'product_id': '4009f09b04',
#                                         'quantity': 2.0,
#                                         'r': '0',
#                                         's': 10.0},
#                                        {'product_id': '833a9b72da',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 93.0},
#                                        {'product_id': '7946f72d59',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 113.0},
#                                        {'product_id': '2824d83a1b',
#                                         'quantity': 3.0,
#                                         'r': '0',
#                                         's': 154.0}],
#                           'rpr': 14.0,
#                           'rps': 0.0,
#                           'store_id': '66cf22fca5',
#                           'sum': 1652.08,
#                           'tid': 'c71cce9fd7'},
#                          {'datetime': '2019-01-07 09:36:03',
#                           'epr': 0.0,
#                           'eps': 0.0,
#                           'products': [{'product_id': '1e177e6400',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 38.0}],
#                           'rpr': 0.1,
#                           'rps': 0.0,
#                           'store_id': '1a346a89e1',
#                           'sum': 37.0,
#                           'tid': '921be2dd68'},
#                          {'datetime': '2019-01-08 11:46:02',
#                           'epr': 0.0,
#                           'eps': 0.0,
#                           'products': [{'product_id': '94b62ffa40',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 75.0},
#                                        {'product_id': 'f7442ec69d',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 43.0}],
#                           'rpr': 0.5,
#                           'rps': 0.0,
#                           'store_id': '1a346a89e1',
#                           'sum': 117.0,
#                           'tid': 'fb07dd7d66'},
#                          {'datetime': '2019-01-10 12:28:53',
#                           'epr': 0.0,
#                           'eps': 0.0,
#                           'products': [{'product_id': 'f6ad31e071',
#                                         'quantity': 0.0,
#                                         'r': '0',
#                                         's': 45.0},
#                                        {'product_id': '8679f046b0',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 40.0},
#                                        {'product_id': 'afc867ea43',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 52.0}],
#                           'rpr': 0.6,
#                           'rps': 0.0,
#                           'store_id': '1a346a89e1',
#                           'sum': 136.0,
#                           'tid': 'b43106ea5d'},
#                          {'datetime': '2019-01-11 12:08:29',
#                           'epr': 0.0,
#                           'eps': 0.0,
#                           'products': [{'product_id': '1e177e6400',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 42.0},
#                                        {'product_id': '94b62ffa40',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 75.0},
#                                        {'product_id': '2e8a393786',
#                                         'quantity': 0.0,
#                                         'r': '0',
#                                         's': 47.0},
#                                        {'product_id': '0434baefd8',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 27.0},
#                                        {'product_id': 'd5b5e81e2b',
#                                         'quantity': 5.0,
#                                         'r': '0',
#                                         's': 28.0},
#                                        {'product_id': '4dcf79043e',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 40.0},
#                                        {'product_id': 'eff2ae1103',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 50.0},
#                                        {'product_id': 'da1c4af3c0',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 50.0}],
#                           'rpr': 1.7,
#                           'rps': 0.0,
#                           'store_id': '1a346a89e1',
#                           'sum': 358.49,
#                           'tid': '7fd510a1bf'},
#                          {'datetime': '2019-01-12 08:24:02',
#                           'epr': 0.0,
#                           'eps': 0.0,
#                           'products': [{'product_id': '122534de50',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 53.0},
#                                        {'product_id': 'f43c12d228',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 36.0},
#                                        {'product_id': '94b62ffa40',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 71.0}],
#                           'rpr': 0.8,
#                           'rps': 0.0,
#                           'store_id': '1a346a89e1',
#                           'sum': 160.0,
#                           'tid': '4a44a51ea2'},
#                          {'datetime': '2019-01-17 11:30:44',
#                           'epr': 0.0,
#                           'eps': 0.0,
#                           'products': [{'product_id': 'f7442ec69d',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 43.0},
#                                        {'product_id': '31dcf71bbd',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 28.0},
#                                        {'product_id': 'eb1560b3c4',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 230.0},
#                                        {'product_id': 'b046129d4d',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 91.0},
#                                        {'product_id': 'f5e18af323',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 77.0},
#                                        {'product_id': 'b6f787d593',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 130.0},
#                                        {'product_id': '5186e12ff4',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 55.0},
#                                        {'product_id': 'c0c8ad4f09',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 230.0}],
#                           'rpr': 5.1,
#                           'rps': 0.0,
#                           'store_id': '1a346a89e1',
#                           'sum': 882.97,
#                           'tid': 'd2c2e27b81'},
#                          {'datetime': '2019-01-18 09:48:58',
#                           'epr': 0.0,
#                           'eps': 0.0,
#                           'products': [{'product_id': 'c5bbae8d2d',
#                                         'quantity': 3.0,
#                                         'r': '0',
#                                         's': 150.0}],
#                           'rpr': 0.7,
#                           'rps': 0.0,
#                           'store_id': '1a346a89e1',
#                           'sum': 149.97,
#                           'tid': 'a85f23a67d'},
#                          {'datetime': '2019-01-24 14:24:57',
#                           'epr': 0.0,
#                           'eps': 0.0,
#                           'products': [{'product_id': 'e6f8ac5174',
#                                         'quantity': 2.0,
#                                         'r': '0',
#                                         's': 14.0},
#                                        {'product_id': 'f7442ec69d',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 43.0},
#                                        {'product_id': '3e038662c0',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 57.0}],
#                           'rpr': 0.5,
#                           'rps': 0.0,
#                           'store_id': '1a346a89e1',
#                           'sum': 113.0,
#                           'tid': '58d9bb7e6f'},
#                          {'datetime': '2019-01-25 14:15:42',
#                           'epr': 0.0,
#                           'eps': 0.0,
#                           'products': [{'product_id': '233eead1ad',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 62.0}],
#                           'rpr': 0.3,
#                           'rps': 0.0,
#                           'store_id': '1a346a89e1',
#                           'sum': 61.0,
#                           'tid': '2999a91bcc'},
#                          {'datetime': '2019-01-26 14:43:40',
#                           'epr': 0.0,
#                           'eps': 0.0,
#                           'products': [{'product_id': 'f43c12d228',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 47.0},
#                                        {'product_id': '94b62ffa40',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 75.0},
#                                        {'product_id': 'c5bbae8d2d',
#                                         'quantity': 3.0,
#                                         'r': '0',
#                                         's': 210.0}],
#                           'rpr': 1.6,
#                           'rps': 0.0,
#                           'store_id': '1a346a89e1',
#                           'sum': 332.0,
#                           'tid': 'bfb461a944'},
#                          {'datetime': '2019-01-27 10:23:02',
#                           'epr': 0.0,
#                           'eps': 0.0,
#                           'products': [{'product_id': '77b36569e2',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 57.0},
#                                        {'product_id': 'c5bbae8d2d',
#                                         'quantity': 2.0,
#                                         'r': '0',
#                                         's': 140.0}],
#                           'rpr': 0.9,
#                           'rps': 0.0,
#                           'store_id': '1a346a89e1',
#                           'sum': 196.0,
#                           'tid': '18617e36bd'},
#                          {'datetime': '2019-01-27 10:27:29',
#                           'epr': 0.0,
#                           'eps': 0.0,
#                           'products': [{'product_id': '66b46b0028',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 45.0}],
#                           'rpr': 0.2,
#                           'rps': 0.0,
#                           'store_id': '1a346a89e1',
#                           'sum': 44.0,
#                           'tid': '701740f723'},
#                          {'datetime': '2019-01-28 10:13:39',
#                           'epr': 0.0,
#                           'eps': 0.0,
#                           'products': [{'product_id': '94b62ffa40',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 75.0},
#                                        {'product_id': '04ef82a636',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 37.0},
#                                        {'product_id': '3c2684d2e5',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 100.0},
#                                        {'product_id': '5cb93c9bc5',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 38.0},
#                                        {'product_id': '35a66faec4',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 89.0},
#                                        {'product_id': 'e7325b4d3a',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 67.0}],
#                           'rpr': 2.0,
#                           'rps': 0.0,
#                           'store_id': '1a346a89e1',
#                           'sum': 406.32,
#                           'tid': '678b918841'},
#                          {'datetime': '2019-01-29 12:34:27',
#                           'epr': 0.0,
#                           'eps': 0.0,
#                           'products': [{'product_id': 'c92d9a946f',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 74.0},
#                                        {'product_id': '04ef82a636',
#                                         'quantity': 2.0,
#                                         'r': '0',
#                                         's': 78.0},
#                                        {'product_id': '94b62ffa40',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 75.0},
#                                        {'product_id': '672c233298',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 44.0},
#                                        {'product_id': '4dcf79043e',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 41.0},
#                                        {'product_id': '3e038662c0',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 72.0},
#                                        {'product_id': 'ebc2d45eb5',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 70.0},
#                                        {'product_id': '5645789fdf',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 47.0},
#                                        {'product_id': '925d3cc556',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 99.0},
#                                        {'product_id': '4009f09b04',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 5.0}],
#                           'rpr': 6.0,
#                           'rps': 0.0,
#                           'store_id': '1a346a89e1',
#                           'sum': 603.59,
#                           'tid': 'b65a6041fc'},
#                          {'datetime': '2019-01-29 12:37:02',
#                           'epr': 0.0,
#                           'eps': 0.0,
#                           'products': [{'product_id': 'ea27d5dc75',
#                                         'quantity': 2.0,
#                                         'r': '0',
#                                         's': 196.0}],
#                           'rpr': 0.9,
#                           'rps': 0.0,
#                           'store_id': '1a346a89e1',
#                           'sum': 196.0,
#                           'tid': 'dd9c4b40e7'},
#                          {'datetime': '2019-01-29 13:28:44',
#                           'epr': 0.0,
#                           'eps': 0.0,
#                           'products': [{'product_id': 'e7325b4d3a',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 67.0}],
#                           'rpr': 0.3,
#                           'rps': 0.0,
#                           'store_id': '1a346a89e1',
#                           'sum': 67.0,
#                           'tid': '67740a654d'},
#                          {'datetime': '2019-02-05 13:23:40',
#                           'epr': 0.0,
#                           'eps': 0.0,
#                           'products': [{'product_id': '85a4571042',
#                                         'quantity': 4.0,
#                                         'r': '0',
#                                         's': 28.0},
#                                        {'product_id': '5645789fdf',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 92.0},
#                                        {'product_id': 'd5b5e81e2b',
#                                         'quantity': 4.0,
#                                         'r': '0',
#                                         's': 22.0}],
#                           'rpr': 0.7,
#                           'rps': 0.0,
#                           'store_id': '1a346a89e1',
#                           'sum': 141.0,
#                           'tid': 'cdc75243ac'},
#                          {'datetime': '2019-02-07 10:22:04',
#                           'epr': 0.0,
#                           'eps': 0.0,
#                           'products': [{'product_id': '1e177e6400',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 44.0},
#                                        {'product_id': 'f7442ec69d',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 43.0},
#                                        {'product_id': '4dcf79043e',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 41.0},
#                                        {'product_id': 'ff5a942bbd',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 60.0},
#                                        {'product_id': '2b9b5bbe40',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 27.0},
#                                        {'product_id': 'fa409f3e9f',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 45.0},
#                                        {'product_id': '1da9db7b6f',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 26.0}],
#                           'rpr': 1.4,
#                           'rps': 0.0,
#                           'store_id': '1a346a89e1',
#                           'sum': 286.23,
#                           'tid': 'd058dbc858'},
#                          {'datetime': '2019-02-09 09:35:05',
#                           'epr': 0.0,
#                           'eps': 0.0,
#                           'products': [{'product_id': '0a3a44d22a',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 55.0},
#                                        {'product_id': 'f43c12d228',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 42.0},
#                                        {'product_id': '42bb7606ea',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 55.0},
#                                        {'product_id': '94b62ffa40',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 65.0}],
#                           'rpr': 1.0,
#                           'rps': 0.0,
#                           'store_id': '1a346a89e1',
#                           'sum': 216.56,
#                           'tid': '41c0049999'},
#                          {'datetime': '2019-02-18 14:39:54',
#                           'epr': 0.0,
#                           'eps': 0.0,
#                           'products': [{'product_id': '7036db4854',
#                                         'quantity': 3.0,
#                                         'r': '0',
#                                         's': 72.0},
#                                        {'product_id': '85a4571042',
#                                         'quantity': 4.0,
#                                         'r': '0',
#                                         's': 25.0},
#                                        {'product_id': 'e7325b4d3a',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 52.0},
#                                        {'product_id': 'f6ebcf3ba5',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 404.0},
#                                        {'product_id': '0fdba91fc0',
#                                         'quantity': 3.0,
#                                         'r': '0',
#                                         's': 296.0},
#                                        {'product_id': 'f4599ca21a',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 0.0},
#                                        {'product_id': 'b046129d4d',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 101.0}],
#                           'rpr': 9.4,
#                           'rps': 0.0,
#                           'store_id': '1a346a89e1',
#                           'sum': 948.75,
#                           'tid': '872a8c1087'},
#                          {'datetime': '2019-02-19 13:30:58',
#                           'epr': 0.0,
#                           'eps': 0.0,
#                           'products': [{'product_id': '4009f09b04',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 5.0},
#                                        {'product_id': '94b62ffa40',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 71.0},
#                                        {'product_id': '86d558ba09',
#                                         'quantity': 2.0,
#                                         'r': '0',
#                                         's': 76.0},
#                                        {'product_id': '4c07cb5835',
#                                         'quantity': 0.0,
#                                         'r': '0',
#                                         's': 39.0},
#                                        {'product_id': 'f5e18af323',
#                                         'quantity': 0.0,
#                                         'r': '0',
#                                         's': 31.0},
#                                        {'product_id': '5cb93c9bc5',
#                                         'quantity': 2.0,
#                                         'r': '0',
#                                         's': 45.0}],
#                           'rpr': 1.3,
#                           'rps': 0.0,
#                           'store_id': '1a346a89e1',
#                           'sum': 266.0,
#                           'tid': '914f01fe23'},
#                          {'datetime': '2019-02-20 12:32:38',
#                           'epr': 0.0,
#                           'eps': 0.0,
#                           'products': [{'product_id': '4bd01c5234',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 60.0},
#                                        {'product_id': '3e038662c0',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 63.0},
#                                        {'product_id': '1972471841',
#                                         'quantity': 0.0,
#                                         'r': '0',
#                                         's': 41.0},
#                                        {'product_id': 'ebc2d45eb5',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 83.0},
#                                        {'product_id': '7118cdd258',
#                                         'quantity': 0.0,
#                                         'r': '0',
#                                         's': 53.0},
#                                        {'product_id': '4c07cb5835',
#                                         'quantity': 0.0,
#                                         'r': '0',
#                                         's': 32.0}],
#                           'rpr': 1.6,
#                           'rps': 0.0,
#                           'store_id': '1a346a89e1',
#                           'sum': 331.41,
#                           'tid': '72bed8566d'},
#                          {'datetime': '2019-02-21 08:41:50',
#                           'epr': 0.0,
#                           'eps': 0.0,
#                           'products': [{'product_id': '785b8ca3d3',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 55.0},
#                                        {'product_id': 'd75fc6ad35',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 52.0},
#                                        {'product_id': '4dcf79043e',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 38.0},
#                                        {'product_id': '1e177e6400',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 44.0},
#                                        {'product_id': 'f5e18af323',
#                                         'quantity': 0.0,
#                                         'r': '0',
#                                         's': 53.0}],
#                           'rpr': 1.2,
#                           'rps': 0.0,
#                           'store_id': '1a346a89e1',
#                           'sum': 241.71,
#                           'tid': '968383c227'},
#                          {'datetime': '2019-02-21 14:39:58',
#                           'epr': 0.0,
#                           'eps': 0.0,
#                           'products': [{'product_id': '5645789fdf',
#                                         'quantity': 2.0,
#                                         'r': '0',
#                                         's': 123.0},
#                                        {'product_id': '717b1090be',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 60.0},
#                                        {'product_id': '4009f09b04',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 5.0},
#                                        {'product_id': '5b379f22d4',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 68.0},
#                                        {'product_id': '07da961099',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 60.0}],
#                           'rpr': 1.5,
#                           'rps': 0.0,
#                           'store_id': '1a346a89e1',
#                           'sum': 316.0,
#                           'tid': '97da6c8cf4'},
#                          {'datetime': '2019-02-22 14:00:37',
#                           'epr': 0.0,
#                           'eps': 0.0,
#                           'products': [{'product_id': 'b046129d4d',
#                                         'quantity': 2.0,
#                                         'r': '0',
#                                         's': 180.0},
#                                        {'product_id': 'a5a4248030',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 162.0}],
#                           'rpr': 1.7,
#                           'rps': 0.0,
#                           'store_id': '1a346a89e1',
#                           'sum': 342.17,
#                           'tid': 'fc5e9eddef'},
#                          {'datetime': '2019-02-22 16:41:42',
#                           'epr': 0.0,
#                           'eps': 0.0,
#                           'products': [{'product_id': 'c92d9a946f',
#                                         'quantity': 2.0,
#                                         'r': '0',
#                                         's': 180.0},
#                                        {'product_id': '4009f09b04',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 5.0},
#                                        {'product_id': '0cbc352942',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 66.0}],
#                           'rpr': 1.2,
#                           'rps': 0.0,
#                           'store_id': '1a346a89e1',
#                           'sum': 250.0,
#                           'tid': '4b16311125'},
#                          {'datetime': '2019-02-23 09:55:11',
#                           'epr': 0.0,
#                           'eps': 0.0,
#                           'products': [{'product_id': '924fb134a1',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 35.0},
#                                        {'product_id': '5ce10128e7',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 54.0},
#                                        {'product_id': 'eaa7a4b6cc',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 38.0}],
#                           'rpr': 0.6,
#                           'rps': 0.0,
#                           'store_id': '1a346a89e1',
#                           'sum': 127.0,
#                           'tid': 'c215aeb90c'},
#                          {'datetime': '2019-02-27 14:06:49',
#                           'epr': 0.0,
#                           'eps': 0.0,
#                           'products': [{'product_id': '55254e0752',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 170.0},
#                                        {'product_id': 'f2d7e365bb',
#                                         'quantity': 1.0,
#                                         'r': '0',
#                                         's': 41.0}],
#                           'rpr': 1.0,
#                           'rps': 0.0,
#                           'store_id': '1a346a89e1',
#                           'sum': 210.78,
#                           'tid': 'f509e3f5fd'}]}

# %%
df_features = pd.read_csv("../../data/preprocessed/client_features.csv")
client_features_dict = dict([(i['client_id'], dict([(k, v) for k, v in i.items() if not k in ("client_id", "target")])) for i in df_features.to_dict("records")])

# %%
from tqdm import tqdm, trange

for i in trange(8):
    l = []
    with open(f"../../data/preprocessed/x5-uplift/0{i}.jsons.splitted", "w") as f:        
        for line in loader(f"../../data/preprocessed/x5-retail-hero/tmp/jsons/0{i}.jsons.splitted"):
            line.update(client_features_dict[line['client_id']])
            del line['target']
            f.write(json.dumps(line)+"\n")
# Out:
# 100%|██████████| 8/8 [00:45<00:00,  5.68s/it]

# %%
line
# Out:
# {'age': 51,
#  'gender': 'U',
#  'client_id': '3831e8106a',
#  'transaction_history': [{'tid': '813440d833',
#    'datetime': '2018-11-22 18:10:30',
#    'products': [{'product_id': '59604886ae',
#      'quantity': 3.0,
#      's': 90.0,
#      'r': '0'},
#     {'product_id': '5ceb8bb1de', 'quantity': 1.0, 's': 43.0, 'r': '0'},
#     {'product_id': '7c7b3f0fd0', 'quantity': 1.0, 's': 50.0, 'r': '0'},
#     {'product_id': '94bfe20a81', 'quantity': 2.0, 's': 67.0, 'r': '0'},
#     {'product_id': 'a0a65ec93d', 'quantity': 3.0, 's': 162.0, 'r': '0'},
#     {'product_id': '3342a7920a', 'quantity': 1.0, 's': 120.0, 'r': '0'},
#     {'product_id': '320e4e901b', 'quantity': 1.0, 's': 100.0, 'r': '0'},
#     {'product_id': '46dca4c97a', 'quantity': 1.0, 's': 47.0, 'r': '0'},
#     {'product_id': '4009f09b04', 'quantity': 1.0, 's': 5.0, 'r': '0'},
#     {'product_id': '52193a3c58', 'quantity': 1.0, 's': 130.0, 'r': '0'},
#     {'product_id': '15ccaa8685', 'quantity': 1.0, 's': 30.0, 'r': '0'}],
#    'rpr': 9.2,
#    'epr': 0.0,
#    'rps': 0.0,
#    'eps': 0.0,
#    'sum': 844.74,
#    'store_id': '59f9933d4a'},
#   {'tid': '4d4eea768d',
#    'datetime': '2018-11-25 19:31:30',
#    'products': [{'product_id': 'd7b46a1f3d',
#      'quantity': 1.0,
#      's': 25.0,
#      'r': '0'},
#     {'product_id': '14c1f7e67f', 'quantity': 2.0, 's': 85.0, 'r': '0'},
#     {'product_id': '9f848b2cb3', 'quantity': 3.0, 's': 101.0, 'r': '0'},
#     {'product_id': '59604886ae', 'quantity': 3.0, 's': 76.0, 'r': '0'},
#     {'product_id': '52ba82a30a', 'quantity': 1.0, 's': 29.0, 'r': '0'},
#     {'product_id': '4009f09b04', 'quantity': 1.0, 's': 4.0, 'r': '0'},
#     {'product_id': 'd850a80f58', 'quantity': 1.0, 's': 152.0, 'r': '0'},
#     {'product_id': '113e3ace79', 'quantity': 2.0, 's': 33.0, 'r': '0'},
#     {'product_id': '15ccaa8685', 'quantity': 1.0, 's': 40.0, 'r': '0'}],
#    'rpr': 3.0,
#    'epr': 0.0,
#    'rps': 0.0,
#    'eps': 0.0,
#    'sum': 546.42,
#    'store_id': '59f9933d4a'},
#   {'tid': '21fd1ad010',
#    'datetime': '2018-11-26 19:56:01',
#    'products': [{'product_id': 'b30d2899b1',
#      'quantity': 1.0,
#      's': 57.0,
#      'r': '0'},
#     {'product_id': '3e038662c0', 'quantity': 1.0, 's': 43.0, 'r': '0'},
#     {'product_id': '5c93519160', 'quantity': 1.0, 's': 98.0, 'r': '0'},
#     {'product_id': '5cb93c9bc5', 'quantity': 1.0, 's': 14.0, 'r': '0'},
#     {'product_id': 'dc2001d036', 'quantity': 1.0, 's': 11.0, 'r': '0'},
#     {'product_id': '343e841aaa', 'quantity': 1.0, 's': 54.0, 'r': '0'}],
#    'rpr': 1.3,
#    'epr': 0.0,
#    'rps': 0.0,
#    'eps': 0.0,
#    'sum': 277.0,
#    'store_id': '59f9933d4a'},
#   {'tid': 'b2a23ac983',
#    'datetime': '2018-12-18 07:53:34',
#    'products': [{'product_id': 'bc430c53f4',
#      'quantity': 10.0,
#      's': 400.0,
#      'r': '0'}],
#    'rpr': 1.9,
#    'epr': 0.0,
#    'rps': 0.0,
#    'eps': 0.0,
#    'sum': 399.9,
#    'store_id': '59f9933d4a'},
#   {'tid': '63b12b509a',
#    'datetime': '2019-01-05 11:10:21',
#    'products': [{'product_id': '4a29330c8d',
#      'quantity': 0.0,
#      's': 10.0,
#      'r': 11.0},
#     {'product_id': '2c61d36698', 'quantity': 1.0, 's': 215.0, 'r': 230.0},
#     {'product_id': '332ef8ff35', 'quantity': 1.0, 's': 252.0, 'r': 270.0}],
#    'rpr': 2.3,
#    'epr': 0.0,
#    'rps': -34.0,
#    'eps': 0.0,
#    'sum': 510.0,
#    'store_id': 'f22887774a'},
#   {'tid': 'fbf2d1236e',
#    'datetime': '2019-01-07 16:37:20',
#    'products': [{'product_id': '322ade8c61',
#      'quantity': 1.0,
#      's': 245.0,
#      'r': '0'},
#     {'product_id': 'df78c57fc5', 'quantity': 1.0, 's': 102.0, 'r': '0'},
#     {'product_id': '032847c028', 'quantity': 1.0, 's': 19.0, 'r': '0'}],
#    'rpr': 0.8,
#    'epr': 0.0,
#    'rps': 0.0,
#    'eps': 0.0,
#    'sum': 366.39,
#    'store_id': '59f9933d4a'},
#   {'tid': '386b42c03a',
#    'datetime': '2019-01-09 15:12:43',
#    'products': [{'product_id': '2c61d36698',
#      'quantity': 1.0,
#      's': 229.0,
#      'r': 230.0},
#     {'product_id': 'c3e3176e84', 'quantity': 1.0, 's': 427.0, 'r': 429.0},
#     {'product_id': '58621557c7', 'quantity': 1.0, 's': 55.0, 'r': 55.0}],
#    'rpr': 7.1,
#    'epr': 0.0,
#    'rps': -3.0,
#    'eps': 0.0,
#    'sum': 713.98,
#    'store_id': 'f22887774a'},
#   {'tid': '6ab440caf8',
#    'datetime': '2019-01-10 17:00:56',
#    'products': [{'product_id': '7ca3d3bbfa',
#      'quantity': 2.0,
#      's': 80.0,
#      'r': '0'},
#     {'product_id': '75f3206dd9', 'quantity': 1.0, 's': 230.0, 'r': '0'},
#     {'product_id': '0434baefd8', 'quantity': 1.0, 's': 31.0, 'r': '0'},
#     {'product_id': 'b30d2899b1', 'quantity': 1.0, 's': 50.0, 'r': '0'},
#     {'product_id': '0e571ffd73', 'quantity': 1.0, 's': 10.0, 'r': '0'},
#     {'product_id': '08594c2778', 'quantity': 1.0, 's': 44.0, 'r': '0'},
#     {'product_id': '3b31f7556b', 'quantity': 1.0, 's': 39.0, 'r': '0'},
#     {'product_id': '4009f09b04', 'quantity': 1.0, 's': 5.0, 'r': '0'},
#     {'product_id': '04387ff3d8', 'quantity': 1.0, 's': 27.0, 'r': '0'},
#     {'product_id': 'a70d997797', 'quantity': 1.0, 's': 62.0, 'r': '0'},
#     {'product_id': 'b9cb88c9fb', 'quantity': 1.0, 's': 32.0, 'r': '0'}],
#    'rpr': 6.1,
#    'epr': 0.0,
#    'rps': 0.0,
#    'eps': 0.0,
#    'sum': 611.1,
#    'store_id': '59f9933d4a'},
#   {'tid': '6d950dbd8a',
#    'datetime': '2019-01-13 14:22:34',
#    'products': [{'product_id': 'a3fa1d23b5',
#      'quantity': 1.0,
#      's': 294.0,
#      'r': '0'},
#     {'product_id': '44947c31be', 'quantity': 1.0, 's': 100.0, 'r': '0'}],
#    'rpr': 0.9,
#    'epr': 0.0,
#    'rps': 0.0,
#    'eps': 0.0,
#    'sum': 393.0,
#    'store_id': '59f9933d4a'},
#   {'tid': '392471fac6',
#    'datetime': '2019-01-15 13:12:59',
#    'products': [{'product_id': '4092fb655a',
#      'quantity': 1.0,
#      's': 28.0,
#      'r': '0'},
#     {'product_id': 'ae75ed821b', 'quantity': 1.0, 's': 59.0, 'r': '0'},
#     {'product_id': 'ac81544ebc', 'quantity': 1.0, 's': 17.0, 'r': '0'},
#     {'product_id': 'a0a65ec93d', 'quantity': 1.0, 's': 52.0, 'r': '0'},
#     {'product_id': 'e47e35856e', 'quantity': 1.0, 's': 41.0, 'r': '0'},
#     {'product_id': 'dc2001d036', 'quantity': 1.0, 's': 12.0, 'r': '0'},
#     {'product_id': '0b33c34a37', 'quantity': 1.0, 's': 33.0, 'r': '0'},
#     {'product_id': '624d99eed1', 'quantity': 1.0, 's': 80.0, 'r': '0'},
#     {'product_id': '75f6fee06b', 'quantity': 1.0, 's': 25.0, 'r': '0'},
#     {'product_id': '0434baefd8', 'quantity': 2.0, 's': 66.0, 'r': '0'},
#     {'product_id': '113e3ace79', 'quantity': 2.0, 's': 71.0, 'r': '0'},
#     {'product_id': '8d4f7352d7', 'quantity': 0.0, 's': 18.0, 'r': '0'},
#     {'product_id': '15ccaa8685', 'quantity': 1.0, 's': 43.0, 'r': '0'},
#     {'product_id': '62b64a60a2', 'quantity': 1.0, 's': 90.0, 'r': '0'}],
#    'rpr': 6.3,
#    'epr': 0.0,
#    'rps': 0.0,
#    'eps': 0.0,
#    'sum': 633.0,
#    'store_id': '59f9933d4a'},
#   {'tid': '0d59e73343',
#    'datetime': '2019-01-19 15:33:50',
#    'products': [{'product_id': '8ee86661c2',
#      'quantity': 2.0,
#      's': 144.0,
#      'r': '0'},
#     {'product_id': 'e01923824a', 'quantity': 1.0, 's': 36.0, 'r': '0'},
#     {'product_id': 'c4390fcd4f', 'quantity': 1.0, 's': 70.0, 'r': '0'},
#     {'product_id': '212f305c8b', 'quantity': 2.0, 's': 500.0, 'r': '0'},
#     {'product_id': '75f3206dd9', 'quantity': 1.0, 's': 230.0, 'r': '0'},
#     {'product_id': '4009f09b04', 'quantity': 1.0, 's': 5.0, 'r': '0'},
#     {'product_id': 'c7fb3a248c', 'quantity': 0.0, 's': 59.0, 'r': '0'},
#     {'product_id': '0495de9a21', 'quantity': 0.0, 's': 34.0, 'r': '0'},
#     {'product_id': 'a375a035b9', 'quantity': 2.0, 's': 38.0, 'r': '0'},
#     {'product_id': '8232171c0d', 'quantity': 4.0, 's': 200.0, 'r': '0'},
#     {'product_id': '032847c028', 'quantity': 2.0, 's': 39.0, 'r': '0'},
#     {'product_id': 'fa8ba5149d', 'quantity': 0.0, 's': 58.0, 'r': '0'},
#     {'product_id': 'a0a65ec93d', 'quantity': 1.0, 's': 50.0, 'r': '0'}],
#    'rpr': 10.5,
#    'epr': 0.0,
#    'rps': 0.0,
#    'eps': 0.0,
#    'sum': 1462.24,
#    'store_id': '59f9933d4a'},
#   {'tid': '9319c14348',
#    'datetime': '2019-02-18 08:23:24',
#    'products': [{'product_id': '94bfe20a81',
#      'quantity': 2.0,
#      's': 66.0,
#      'r': '0'},
#     {'product_id': 'dba3bde280', 'quantity': 1.0, 's': 43.0, 'r': '0'},
#     {'product_id': '90e1c8e54e', 'quantity': 1.0, 's': 24.0, 'r': '0'},
#     {'product_id': '2c7d781ce1', 'quantity': 1.0, 's': 54.0, 'r': '0'}],
#    'rpr': 0.9,
#    'epr': 0.0,
#    'rps': 0.0,
#    'eps': 0.0,
#    'sum': 186.0,
#    'store_id': '59f9933d4a'},
#   {'tid': '91ae113132',
#    'datetime': '2019-03-08 11:57:44',
#    'products': [{'product_id': 'cc59e17e15',
#      'quantity': 1.0,
#      's': 44.0,
#      'r': '0'},
#     {'product_id': '4a29330c8d', 'quantity': 0.0, 's': 14.0, 'r': '0'},
#     {'product_id': '09cfdc96e2', 'quantity': 1.0, 's': 200.0, 'r': '0'},
#     {'product_id': 'cdcf6031a8', 'quantity': 1.0, 's': 145.0, 'r': '0'},
#     {'product_id': '0e571ffd73', 'quantity': 1.0, 's': 10.0, 'r': '0'},
#     {'product_id': '9bb48a3cb2', 'quantity': 1.0, 's': 130.0, 'r': '0'},
#     {'product_id': '893ef35102', 'quantity': 1.0, 's': 20.0, 'r': '0'}],
#    'rpr': 5.6,
#    'epr': 0.0,
#    'rps': 0.0,
#    'eps': 0.0,
#    'sum': 563.25,
#    'store_id': 'f22887774a'}],
#  'first_issue_time': 0.06573433536276002,
#  'first_redeem_time': 0.29972434677828513,
#  'issue_redeem_delay': 0.2339900114155251,
#  'F': 0,
#  'M': 0,
#  'U': 1}
